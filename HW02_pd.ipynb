# %% [markdown]
# # Q1. 引入 train.csv 資料集

# %%
import pandas as pd

# %%
traing = pd.read_csv("C:/Users/Elaina/python/玉山/train.csv")
traing
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q2. 將 traing 資料的資料欄位名稱存成 list

# %%
col_name = traing.columns
col_name
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(col_name)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# # Q3. traing 資料集年齡最大跟最小的是?

# %%
age = traing['Age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
max(age)
# Out:
# 80.0

# %%
min(age)
# Out:
# 0.42

# %% [markdown]
# # Q4. 這個 traing 資料集，各欄位遺漏值狀況為何?

# %%
# ans.
def count_col_null(df):
    
    '''
    Args:
        df: input dataframe
    Return:
        null_data_df: to count null by each column
    '''
    
    null_data = []
    for i in range(len(df.columns)):
        null_data.append(sum(df.iloc[:, i].isnull()))
    
    null_data_df = pd.DataFrame({
                   "columns": list(df.columns),
                   "null_counts": null_data
                    })
    
    return null_data_df

# %%
count_col_null(traing)
# Out:
#         columns  null_counts
# 0   PassengerId            0
# 1      Survived            0
# 2        Pclass            0
# 3          Name            0
# 4           Sex            0
# 5           Age          177
# 6         SibSp            0
# 7         Parch            0
# 8        Ticket            0
# 9          Fare            0
# 10        Cabin          687
# 11     Embarked            2

# %%
# mine

# %%
traing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
null_data = []
for i in list(traing.columns):
    null_count = sum(traing[i].isnull())
    null_data.append(null_count)
    
null_data_df = pd.DataFrame({
    'column': list(traing.columns),
    'num': null_data
})

null_data_df
# Out:
#          column  num
# 0   PassengerId    0
# 1      Survived    0
# 2        Pclass    0
# 3          Name    0
# 4           Sex    0
# 5           Age  177
# 6         SibSp    0
# 7         Parch    0
# 8        Ticket    0
# 9          Fare    0
# 10        Cabin  687
# 11     Embarked    2

# %% [markdown]
# # Q5. 計算 traing 資料集男女的存活率

# %%
# ans.
print(traing.Survived[traing.Sex == 'male'].value_counts(normalize = True))

print(traing.Survived[traing.Sex == 'female'].value_counts(normalize = True))
# Out:
# 0    0.811092
# 1    0.188908
# Name: Survived, dtype: float64
# 1    0.742038
# 0    0.257962
# Name: Survived, dtype: float64

# %%
# mine

# %%
traing
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
alive = traing.groupby(by = ['Sex', 'Survived']).count()['PassengerId']
alive
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
num = traing.groupby(by = 'Sex').count()['PassengerId']
num
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
# female
print(233*100/314)

# male
print(109*100/577)
# Out:
# 74.20382165605096
# 18.890814558058924

# %% [markdown]
# # Q6. 計算 traing 資料集名稱有 Mr. 是幾人

# %%
# ans.
len(traing[traing.Name.str.find('Mr.') != -1])
# 如果找不到要搜索的字符串，則find()返回-1
# Out:
# 517

# %% [markdown]
# # Q7. traing 資料集總共有幾種票價

# %%
traing.value_counts('Fare')
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.1125      1
# 8.1375      1
# 17.4000     1
# 8.1583      1
# 7.7292      1
# Length: 248, dtype: int64

# %%
len(traing.value_counts('Fare'))
# Out:
# 248

# %% [markdown]
# # Q8. 依據是否生存為群組，traing 資料集分別計算票價和年齡的總和、平均數、中位數

# %%
# ans.
import numpy as np
traing.groupby(by = 'Survived')['Fare', 'Age'].agg([np.sum, np.mean, np.median])
# Out:
# C:\Users\Elaina\AppData\Local\Temp/ipykernel_18728/2658997076.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   traing.groupby(by = 'Survived')['Fare', 'Age'].agg([np.sum, np.mean, np.median])
#                 Fare                         Age
#                  sum       mean median       sum       mean median
# Survived
# 0         12142.7199  22.117887   10.5  12985.50  30.626179   28.0
# 1         16551.2294  48.395408   26.0   8219.67  28.343690   28.0

# %%
traing.groupby(by = 'Survived')['Fare', 'Age'].sum()
# Out:
# C:\Users\Elaina\AppData\Local\Temp/ipykernel_18728/945685871.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   traing.groupby(by = 'Survived')['Fare', 'Age'].sum()
#                 Fare       Age
# Survived
# 0         12142.7199  12985.50
# 1         16551.2294   8219.67

# %%
# mine

# %%
print(traing.groupby(by = 'Survived').sum()['Fare'])
print(traing.groupby(by = 'Survived').mean()['Fare'])
print(traing.groupby(by = 'Survived').median()['Fare'])
# Out:
# Survived
# 0    12142.7199
# 1    16551.2294
# Name: Fare, dtype: float64
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64
# Survived
# 0    10.5
# 1    26.0
# Name: Fare, dtype: float64

# %%
print(traing.groupby(by = 'Survived').sum()['Age'])
print(traing.groupby(by = 'Survived').mean()['Age'])
print(traing.groupby(by = 'Survived').median()['Age'])
# Out:
# Survived
# 0    12985.50
# 1     8219.67
# Name: Age, dtype: float64
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64
# Survived
# 0    28.0
# 1    28.0
# Name: Age, dtype: float64

# %% [markdown]
# # Q9. train 資料集中，依據Embarked分組計算每個欄位的平均數、最小值、最大值、中位數

# %%
# ans.
traing.groupby('Embarked').agg([np.mean, np.min, np.max, np.median])
# Out:
#          PassengerId                   Survived                     Pclass  \
#                 mean amin amax median      mean amin amax median      mean
# Embarked
# C         445.357143    2  890  455.0  0.553571    0    1    1.0  1.886905
# Q         417.896104    6  891  389.0  0.389610    0    1    0.0  2.909091
# S         449.527950    1  889  447.5  0.336957    0    1    0.0  2.350932
#
#                ... SibSp            Parch                        Fare          \
#          amin  ...  amax median      mean amin amax median       mean    amin
# Embarked       ...
# C           1  ...     2    0.0  0.363095    0    3    0.0  59.954144  4.0125
# Q           1  ...     4    0.0  0.168831    0    5    0.0  13.276030  6.7500
# S           1  ...     8    0.0  0.413043    0    6    0.0  27.079812  0.0000
#
#
#               amax median
# Embarked
# C         512.3292  29.70
# Q          90.0000   7.75
# S         263.0000  13.00
#
# [3 rows x 28 columns]

# %%
# mine

# %%
traing.groupby(by = 'Embarked').mean()
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          445.357143  0.553571  1.886905  30.814769  0.386905  0.363095
# Q          417.896104  0.389610  2.909091  28.089286  0.428571  0.168831
# S          449.527950  0.336957  2.350932  29.445397  0.571429  0.413043
#
#                Fare
# Embarked
# C         59.954144
# Q         13.276030
# S         27.079812

# %%
traing.groupby(by = 'Embarked').min()
# Out:
# C:\Users\Elaina\AppData\Local\Temp/ipykernel_3184/3671547614.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   traing.groupby(by = 'Embarked').min()
#           PassengerId  Survived  Pclass                 Name     Sex   Age  \
# Embarked
# C                   2         0       1  Abelson, Mr. Samuel  female  0.42
# Q                   6         0       1   Bourke, Miss. Mary  female  2.00
# S                   1         0       1  Abbing, Mr. Anthony  female  0.67
#
#           SibSp  Parch  Ticket    Fare
# Embarked
# C             0      0  110813  4.0125
# Q             0      0   12460  6.7500
# S             0      0  110152  0.0000

# %%
traing.groupby(by = 'Embarked').max()
# Out:
# C:\Users\Elaina\AppData\Local\Temp/ipykernel_3184/4273233342.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   traing.groupby(by = 'Embarked').max()
#           PassengerId  Survived  Pclass                         Name   Sex  \
# Embarked
# C                 890         1       3    del Carlo, Mr. Sebastiano  male
# Q                 891         1       3             Tobin, Mr. Roger  male
# S                 889         1       3  van Melkebeke, Mr. Philemon  male
#
#            Age  SibSp  Parch         Ticket      Fare
# Embarked
# C         71.0      2      3  SC/Paris 2163  512.3292
# Q         70.5      4      5     A/5. 13032   90.0000
# S         80.0      8      6      WE/P 5735  263.0000

# %%
traing.groupby(by = 'Embarked').median()
# Out:
#           PassengerId  Survived  Pclass   Age  SibSp  Parch   Fare
# Embarked
# C               455.0       1.0     1.0  29.0    0.0    0.0  29.70
# Q               389.0       0.0     3.0  27.0    0.0    0.0   7.75
# S               447.5       0.0     3.0  28.0    0.0    0.0  13.00

# %% [markdown]
# # Q10. train 資料集中，回答超過60歲的男生且登船是C或Ｑ的人數

# %%
traing.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
condition = (traing['Age'] > 60) & (traing['Sex'] == 'male') & (traing['Embarked'].isin(['C', 'Q'])) 
traing[condition]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 116          117         0       3            Connors, Mr. Patrick  male
# 280          281         0       3                Duane, Mr. Frank  male
# 493          494         0       1         Artagaveytia, Mr. Ramon  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 54   65.0      0      1    113509  61.9792   B30        C
# 96   71.0      0      0  PC 17754  34.6542    A5        C
# 116  70.5      0      0    370369   7.7500   NaN        Q
# 280  65.0      0      0    336439   7.7500   NaN        Q
# 493  71.0      0      0  PC 17609  49.5042   NaN        C

# %%
len(traing[condition])
# Out:
# 5

# %% [markdown]
# # Q11. train 資料集中，找到index3到7的所有資料

# %%
# ans.
traing.iloc[3:8, :]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                Palsson, Master. Gosta Leonard    male   2.0      3      1
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
# 7  349909  21.0750   NaN        S

# %%
# mine

# %%
traing[3:8]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                Palsson, Master. Gosta Leonard    male   2.0      3      1
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
# 7  349909  21.0750   NaN        S

# %% [markdown]
# # Q12. train 資料集中，依照 Age、Fare 遞增排序資料

# %%
traing.sort_values(['Age', 'Fare'])
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q13. train 資料集中，把male換成男生、female換成女生

# %%
# ans.
traing['new_SEX'] = traing.Sex.map({'male': '男生', 'female': '女生'})
traing
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
traing.drop(['new_SEX'], axis = 1, inplace = True)
traing
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# mine

# %%
def chinesesex(df):
    if df['Sex'] == 'male':
        return '男生'
    
    elif df['Sex'] =='female':
        return '女生'

# %%
traing['Q13_chinesesex'] = traing.apply(chinesesex, axis = 1)
traing
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q14. 將 train 和 test 合併起來為 data 資料集

# %%
train = pd.read_csv("C:/Users/Elaina/python/玉山/train.csv")
test = pd.read_csv("C:/Users/Elaina/python/玉山/test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data = pd.concat([train, test]).reset_index(drop = True)
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# # Q15. 在 data 資料集，新增一個欄位年齡分組，分為以下群組(20歲以下、21歲-40歲、41歲-60歲、61歲-80歲、81歲-100歲、101歲以上)

# %%
def agegroup(df):
    if df['Age'] <= 20:
        return '20歲以下'
    elif 21 <= df['Age'] <= 40:
        return '21歲-40歲'
    elif 41 <= df['Age'] <= 60:
        return '41歲-60歲'
    elif 61 <= df['Age'] <= 80:
        return '61歲-80歲'
    elif 81 <= df['Age'] <= 100:
        return '81歲-100歲'
    elif df['Age'] >= 101:
        return '101歲以上'
    else:
        return 'error'

# %%
data['agegroup'] = data.apply(agegroup, axis = 1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
